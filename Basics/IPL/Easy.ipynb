# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("EASY_IPL.xlsx", sheet_name="All_IPL_Data")

df
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008     Mohali            Chennai
# 2               3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3               4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4               5  League Match  Apr 20  2008     Mumbai             Mumbai
# ..            ...           ...     ...   ...        ...                ...
# 509           510  League Match  May 17  2015  Hyderabad          Hyderabad
# 510           511   Qualifier 1  May 19  2015     Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015       Pune          Bangalore
# 512           513   Qualifier 2  May 22  2015     Ranchi          Bangalore
# 513           426  League Match   May 7  2014    Cuttack             Punjab
#
# ...

# %%
# Data cleaning

df = df.fillna("NaN")

# %%
df.groupby("Year")["Winning_Team"].value_counts()
# df[df["Team_Batting_Second"]==df["Winner"]]
# df[df["Year"]==2008]
# Out:
# Year  Winning_Team
# 2008  Chasing         36
#       FirstBatting    22
# 2009  Chasing         30
#       FirstBatting    26
#       Match Tied       1
# 2010  FirstBatting    31
#       Chasing         28
#       Match Tied       1
# 2011  Chasing         40
#       FirstBatting    32
# 2012  Chasing         40
#       FirstBatting    34
# 2013  Chasing         37
#       FirstBatting    37
#       Match Tied       2
# 2014  Chasing         37
#       FirstBatting    22
#       Match Tied       1
# 2015  FirstBatting    32
#       Chasing         24
#       Match Tied       1
# Name: count, dtype: int64
