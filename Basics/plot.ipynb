# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-4, 4, 1000)
sin = np.sin(x)
cos = np.cos(x)
plt.plot(x, sin, label="Sin")
plt.plot(x, cos, label="Cos")
plt.xticks(range(int(x[0]), int(x[-1])))
pass
diff = sin-cos
intersection_x = []
for i in range(len(x) - 1):
    if (sin[i] - cos[i]) * (sin[i + 1] - cos[i + 1]) < 0:
        intersection_x.append(i)

for i in intersection_x:
    plt.axvline(x[i], color="#333", linestyle="--", lw=1.5)

plt.fill_between(x, sin, color="red", alpha=.2)
plt.fill_between(x, cos, color="blue", alpha=.2)

plt.xlabel("Value")
plt.ylabel("Sin/Cos")
plt.legend(loc="upper right",shadow=True, fancybox=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.random.seed(np.random.randint(1, 500))
cols = ['red', 'blue', 'green', 'orange', 'yellow', 'gray', 'pink']
xcoords = np.array([1,2,3,4,5,6,7])
ycoords = np.random.normal(loc=0, scale=1.2, size=xcoords.shape)
plt.scatter(xcoords, ycoords, c = cols, marker='o', s=50)
plt.xlim((-3,20))
plt.ylim((-5,5))
plt.show()
